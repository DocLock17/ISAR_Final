# %% [markdown]
# <a href="https://colab.research.google.com/github/DocLock17/ISAR_Final/blob/main/20kDemonAttack1_MAT_Suite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modular Abstraction Transfer Suite
#
# ### A Deep Mind Based Experimental Platform For Reasearch In Abstaction And Generalization

# %% [markdown]
# We set out to assemble a team of Algorithms to fight the evil of an unseen game. Unfortunately, this task became nearly insurmountable. First iterations of the code were based implementations using a deque for replay memory, and using a single instance training loop. These systems did show promise in early experiments but were so inefficient that it would have likely taken months of training to reach a respectable level let alone expert level game play.
#
# The solution it seems is multi-part, so we will spread out the explanations here.
#
# |
# Great References:
#
# https://towardsdatascience.com/tutorial-double-deep-q-learning-with-dueling-network-architectures-4c1b3fb7f756
#
# https://keras.io/examples/rl/deep_q_network_breakout/
#
# https://stackoverflow.com/questions/15455048/releasing-memory-in-python
#
# Official Citations in accompanying paper

# %% [markdown]
# #### Interactive Playgound (run after notebook)

# %%
# # # Run From Top (Hint: It must be loaded commented first)
# myPlayground()

# %% [markdown]
# #### Selector Menu

# %%
##   Game Selector
ENVIRONMENT_NAME = 'DemonAttackNoFrameskip-v4' #@param ['Atlantis-v0', 'DemonAttack-v0', 'Phoenix-v0', 'Riverraid-v0', 'Solaris-v0', 'Asterix-v0', 'Breakout-v0', 'Boxing-v0', 'Pong-v0', 'BattleZone-v0', 'SpaceInvaders-v0', 'BeamRider-v0','AtlantisNoFrameskip-v4', 'DemonAttackNoFrameskip-v4', 'PhoenixNoFrameskip-v4', 'RiverraidNoFrameskip-v4', 'SolarisNoFrameskip-v4', 'AsterixNoFrameskip-v4', 'BreakoutNoFrameskip-v4', 'BoxingNoFrameskip-v4', 'PongNoFrameskip-v4', 'BattleZoneNoFrameskip-v4', 'SpaceInvadersNoFrameskip-v4', 'BeamRiderNoFrameskip-v4']

# Render gameplay in cell or viewer
RENDER = False #@param {type:"boolean"}

# Slow down game play and discontinue training for observation
OBSERVATION_MODE = False #@param {type:"boolean"}

# Display Text Output to Observe Activations and Q Updates
DIAGNOSTIC_MODE = False #@param {type:"boolean"}

## Chippie the Progress Bot Settings       (Name courtesy of: Kylie Locker)
CHIPPIE_PROGESS_REPORTS = True #@param {type:"boolean"}
# Row for progress bot stacking ( 1, 8, 12 )
MAX_CHIPPIES_ROW = 8 #@param {type:"integer"}

# Provide GPU information
USE_GPU_SUPPORT = True #@param {type:"boolean"}


## Data Settings
# Import and Unzip Hosted Dataset
CREATE_MISSING_DIRECTORIES = True #@param {type:"boolean"}
IMPORT_MAIN_DATA = True #@param {type:"boolean"}
IMPORT_SENTIMENT_DATA = True #@param {type:"boolean"}
IMPORT_MODEL_DATA = True #@param {type:"boolean"}


## Agent Settings
# Parameters
n_episodes = 100000 #@param {type:"integer"}
BATCH_SIZE =  32#@param {type:"integer"}
action_steps =  4#@param {type:"integer"}
skip_start = 1 #@param {type:"integer"}
agent_gamma = 0.985 #@param {type:"slider", min:0, max:1, step:0.0001}
agent_epsilon = 1.0 #@param {type:"slider", min:0, max:1, step:0.0001}
agent_epsilon_decay = 0.9999 #@param {type:"slider", min:0.5, max:1.000, step:0.0001}
agent_epsilon_min = 0.1 #@param {type:"slider", min:0, max:1.000, step:0.0001}
agent_learning_rate = 0.00025 #@param {type:"number", min:0.0000, max:0.0200, step:0.00001}
# lr=0.00042 # lr=0.00125 #lr=0.00025
# agent_learning_rate = 0.00025 # works??
## Buffer Settings
STARTING_MEMORY_SIZE = 75000#@param {type:"integer"}
MAX_MEMORY_LENGTH = 150000 #@param {type:"integer"}
Q_UPDATE_FREQUENCY = 10000 #@param {type:"integer"}

# Pre Buffer Guidance
WINDOW_SIZE = (84, 84)

# Sub-Model Settings
SLICE_ONE_NAME = "s1_MAT_ImageClassifier_v5" #@param {type:"string"}
SLICE_ONE_TRAINABLE = False #@param {type:"boolean"}
SLICE_ONE_CHECKPOINT = False #@param {type:"boolean"}

SLICE_TWO_NAME = "s2_MAT_ImageClassifier_v5" #@param {type:"string"}
SLICE_TWO_TRAINABLE = True #@param {type:"boolean"}
SLICE_TWO_CHECKPOINT = True #@param {type:"boolean"}

SLICE_THREE_NAME = "s3_MAT_ImageClassifier_v2" #@param {type:"string"}
SLICE_THREE_TRAINABLE = True #@param {type:"boolean"}
SLICE_THREE_CHECKPOINT = True #@param {type:"boolean"}

FULL_MODEL_NAME = "s2_MAT_Agent_Testing_v2" #@param {type:"string"}
FULL_MODEL_TRAINABLE = True #@param {type:"boolean"}
FULL_MODEL_CHECKPOINT = True #@param {type:"boolean"}

CHECKPOINT_FREQUENCY =  1000#@param {type:"integer"}

SAVE_AGENT = True #@param {type:"boolean"}

## Game selector feedback
print("Selected Game: " + ENVIRONMENT_NAME)
# Out:
# Selected Game: DemonAttackNoFrameskip-v4

# %% [markdown]
# #### Setup Model Output Directory

# %%
# %%capture

import os

try:
  import google.colab
  # !pip install baselines
  COLAB = True
  
except:
  # !pip install gdown
  COLAB = False

model_dir = 'ISAR_Model_Data'
data_dir = 'ISAR_Main_Classification'
transfer_dir = 'ISAR_Sentiment_Transfer'


if IMPORT_MAIN_DATA :
    if not os.path.exists(data_dir): ## Make it if it doesn't exist
      # !gdown https://drive.google.com/uc?id=1P7o1x4ZpPbd16VQDwaMzllbN-tlfqqIH
      # !unzip ISAR_Main_Classification.zip
      # !rm ISAR_Main_Classification.zip
if IMPORT_SENTIMENT_DATA:
    if not os.path.exists(transfer_dir): ## Make it if it doesn't exist
      # !gdown https://drive.google.com/uc?id=1UDUNnw04q5cvms5ibM6pNn-wXtJphXxZ
      # !unzip ISAR_Sentiment_Transfer.zip
      # !rm ISAR_Sentiment_Transfer.zip
if IMPORT_MODEL_DATA:
    if not os.path.exists(model_dir): ## Make it if it doesn't exist
      # !gdown https://drive.google.com/uc?id=1DIc_J6XyKzNDSMjSbGkt3vzQep4YUEYU
      # !unzip ISAR_Model_Data.zip
      # !rm ISAR_Model_Data.zip

# %%
if CREATE_MISSING_DIRECTORIES:  
  if not os.path.exists(data_dir): ## Make it if it doesn't exist
    print("Creating Main Data Directory")
    os.makedirs(data_dir)
  else:
    print("Main Data Directory Found")
  if not os.path.exists(transfer_dir): ## Make it if it doesn't exist
    print("Creating Transfer Data Directory")
    os.makedirs(transfer_dir)
  else:
    print("Transfer Data Directory Found")
  if not os.path.exists(model_dir): ## Make it if it doesn't exist
    print("Creating Model Directory")
    os.makedirs(model_dir)
  else:
    print("Model Directory Found")
# Out:
# Main Data Directory Found
# Transfer Data Directory Found
# Model Directory Found

# %% [markdown]
# #### Setup Imports

# %%
## Begin by importing . . .  oh . . . everything!
try:
  import math
  import random
  import numpy as np

  import glob
  import io
  import base64
  from time import sleep

  from collections import deque

  import gym
  import tensorflow as tf
  import tensorflow_hub as hub
  from tensorflow.keras.models import Sequential
  from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, BatchNormalization
  from tensorflow.keras.optimizers import Nadam, Adam
  from tensorflow import keras

  import matplotlib
  import matplotlib.pyplot as plt
  # %matplotlib inline

  from IPython.display import HTML
  from IPython import display as ipythondisplay
  from IPython.display import clear_output
  
  from gym.wrappers.atari_preprocessing import AtariPreprocessing
  from baselines.common.atari_wrappers import make_atari, EpisodicLifeEnv, WarpFrame, ScaledFloatFrame, ClipRewardEnv, FrameStack, FireResetEnv



except:
  # %%capture
  if COLAB:
    ## For colab we must install some dependancies
    # !pip install baselines
    # !apt-get install -y xvfb x11-utils
    ## Next we will need to install a virtual display and correct Open AI installation
    # !pip install gym[all]==0.17.3
    # !pip install pyvirtualdisplay==0.2.* 
    # !pip install PyOpenGL==3.1.* 
    # !pip install PyOpenGL-accelerate==3.1.*
    # !pip install pyglet
    # So let's setup the virtual display
    import pyvirtualdisplay
    # use False with Xvfb
    _display = pyvirtualdisplay.Display(visible=False, size=(1400, 900))
    _ = _display.start()
    # Now Check the Display
    # !echo $DISPLAY

if USE_GPU_SUPPORT:
  print("TF version:", tf.__version__)
  print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

  # Set Memory Growth
  gpus = tf.config.experimental.list_physical_devices('GPU')
  if gpus:
    try:
      # Currently, memory growth needs to be the same across GPUs
      for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
        print(gpu)
      logical_gpus = tf.config.experimental.list_logical_devices('GPU')
      print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
      # Memory growth must be set before GPUs have been initialized
      print(e)
# Out:
# TF version: 2.4.1
# Num GPUs Available:  2
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')
# 2 Physical GPUs, 2 Logical GPUs

# %% [markdown]
# #### The Wrappers
# So here we will use some wrappers from the baselines package. This broke my Tensorflow installation on my home server so I avoided wrappers during the majority of this project however, in the end using the optimized implementations in the wrapper drove speed up 1000% or so. So, if you are implementing your own version of this experiment, I cannot stress enough how important it is to study up on these wrappers to start.

# %%
# Make Environment

env = make_atari(ENVIRONMENT_NAME)
env = EpisodicLifeEnv(env)

if 'FIRE' in env.unwrapped.get_action_meanings():
        env = FireResetEnv(env)

env = WarpFrame(env)

env = ScaledFloatFrame(env)

env = ClipRewardEnv(env)

env = FrameStack(env, 3)

# myWrappedEnv = FrameStack(atariWrap, 3)                  env_wrappers=[lambda env: ActionRepeat(env, times=4)])
env.seed(42)
np.random.seed(42)
tf.random.set_seed(42)
# env = gym.make(ENVIRONMENT_NAME)
state_size = (84, 84, 3)
action_size = env.action_space.n

# %% [markdown]
# #### Setup Progress Bot
#
# Here we find Chippie the progress bot, I in the hours of waiting for code to test and the constant need to debug I created a simple progress bar that slowly turned into an entire diagnostic companion. However, as debugging reveiled greater and greater speed enhancements, Chippies output is limited to every 250 Episodes now and his diagnostic features removed or turned off.
#
# As one benefit, note that when using Gradient tape we don't get standard output from tensorflow so Chippie's periodic reports include leading and trailing averages of the last 1000, and previous 1000 loss calculations allowing us to see how our agent is progressing through the training process. If you are tinkering with the code you might try out the diagnostic mode to get a snap shot of the DQN learning process as it is actually happening.

# %%
# import gc
import sys

class ChippieProgressBot:

    def __init__(self, window_size=100, row_configuration=8, log_size=2000):
        self.rowCount = 0
        self.miniScore = 0
        self.movingAverage = []
        self.windowSize = window_size
        self.facelist1 = ["~{0_0}~","~{o_o}~","~{o_0}~","~{0_o}~"]
        self.row_configuration = row_configuration
        self.lossLog = []
        self.logSize = log_size
        self.lessChippies = True
        self.skippedChippies = 250

    def training(self, score):
      if not self.lessChippies:
        if self.miniScore < score:
            self.miniScore += 1
            print(self.facelist1[int(self.miniScore % 4)] + str(int(score))+"   ", end='')
            self.rowCount += 1
            if self.rowCount >= self.row_configuration:
                print("\n")
                self.rowCount = 0
        else:
           return
      else:
        return


    def q_update(self):
      if not self.lessChippies:
        print("""  {-_-}    """, end='')
        self.rowCount += 1
        if self.rowCount >= MAX_CHIPPIES_ROW:
            print("\n")
            self.rowCount = 0
      else:
        return

    def dead(self, score, totalScore, episode, completion_target,  survived, experiance, memory, epsilon):
      
        if len(self.movingAverage) >= self.windowSize:
          del self.movingAverage[:1]
        self.movingAverage.append(score)
        if len(self.lossLog) > 2:
          trailing = sum(self.lossLog[:len(self.lossLog)//2])/(len(self.lossLog)*0.5)

          leading = sum(self.lossLog[len(self.lossLog)//2:])/(len(self.lossLog)*0.5)

        self.rowCount = 0
        self.miniScore = 0
        if not self.lessChippies:

          # running_reward = np.mean(episode_reward_history)
          print(""" `{x_X}~   """+"\n")

          print("Episode: {}/{}, Episode Score: {}, Avg Episode Score: {:.4}, Survival Time: {}"
          .format(episode+1, completion_target, score, totalScore/(episode+1), survived)+"\n")

          print("Your agent has a running average Score per 100 episodes of: \{^,^}~"+"{:.3}"
          .format(sum(self.movingAverage)/len(self.movingAverage))+"\n")

          print("Total Steps: {}, Memory Size: {}, Current Epsilon Value: {:.2}, Leading Loss: {:.4}/ Trailing Loss: {:.4}"
          .format(experiance, memory, epsilon, leading, trailing)+"\n\n")

        
        else:
          if (episode+1) % self.skippedChippies == 0:

            print("\n"+"Episode: {}/{}, Episode Score: {}, Avg Episode Score: {:.4}, Survival Time: {}"
            .format(episode+1, completion_target, score, totalScore/(episode+1), survived))

            print("Your agent has a running average Score per 100 episodes of: \{^,^}~"+"{:.3}"
            .format(sum(self.movingAverage)/len(self.movingAverage)))

            print("Total Steps: {}, Memory Size: {}, Current Epsilon Value: {:.2}, Leading Loss: {:.4}/ Trailing Loss: {:.4}"
            .format(experiance, memory, epsilon, leading, trailing)) 
          else:
            return


    def logLoss(self, loss):
        if len(self.lossLog) >= self.logSize:
            del self.lossLog[:1]
        self.lossLog.append(loss)
        # trailing = sum(self.lossLog[:len(self.lossLog)//2])/(len(self.lossLog)*0.5)
        # print(leading)
        # leading = sum(self.lossLog[len(self.lossLog)//2:])/(len(self.lossLog)*0.5)
        # print(trailing)

# chippie.training(score)
chippie = ChippieProgressBot(window_size=100, row_configuration=MAX_CHIPPIES_ROW)

# %% [markdown]
# #### The Frame PreProcessor and Ring Buffer that was: New Replay Memory
#
# After managing to make batches acceptable to the TensorFlow's .fit() method, we noticed a massive increase in training speed. The victory was short lived, however, as memory usage skyrocket outside the limits of both colaboratory and one local workstation (128GB). So, both the deque and image pre-processors had to be re-examined. This resulted in a home brewed ring buffer and numpy base preprocessor being implemented, which monumentally increased speed. Implementing the image pre-processor buffer using numpy arrays saved a few extra operations so I am confident this was all we cound do. However, in the final edit we realized that the FrameStack Wrapper from the Baselines package could be instantiated with 3 frame setting rendering this preprocessor no longer necessary and implemented a rotating list ring buffer based on Geron's implementation which provides the random access benefits of our ring buffer that doesn' waste cpu cycles moving indices.

# %%
# Geron provides a great note on this buffer design that creates significant speed increases.
class ReplayMemory:
    def __init__(self, max_size):
        self.buffer = np.empty(max_size, dtype=np.object)
        self.max_size = max_size
        self.index = 0
        self.size = 0

    def append(self, obj):
        self.buffer[self.index] = obj
        self.size = min(self.size + 1, self.max_size)
        self.index = (self.index + 1) % self.max_size

    def sample(self, batch_size):
        indices = np.random.randint(self.size, size=batch_size)
        return self.buffer[indices]

# %% [markdown]
# #### Define the agent
#
# In the search for optimization, we found a few pointers to use variance scaling in layer declaration. I include the links for a deeper dive, however essentially this means that the initiallization of weights and biases are resricted to a range with a standard deviation of <= 2.0. This makes sense since the Q-values we are hoping for will yield need to be close to each other to promote further explorations.
#
#
# After, careful examination of a much faster implementation attempting to solve the traditional 4-frame 84x84 version was very helpful. So, we took time to implement the network using GradientTape(), which made the code run about twice as fast.

# %%
class DQNAgent:

    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.replay_memory = ReplayMemory(max_size=100000)

        
        self.update_rate = Q_UPDATE_FREQUENCY # Number of steps until updating the target network

        self.gamma = agent_gamma # decay or discount rate

        self.epsilon = agent_epsilon # exploration rate
        self.epsilon_decay = agent_epsilon_decay # exploration decay
        self.epsilon_min = agent_epsilon_min # min exploration

        self.learning_rate = agent_learning_rate # SGD or Nadam rate param

        # self.model, self.sliceOne, self.sliceTwo, self.sliceThree = self._build_new_model()
        # self.target_model, self.target_sliceOne, self.target_sliceTwo, self.target_sliceThree = self._build_new_model()

        # self.model, self.sliceOne, self.sliceTwo, self.sliceThree = self._build_1S_transfer_model()
        # self.target_model, self.target_sliceOne, self.target_sliceTwo, self.target_sliceThree = self._build_1S_transfer_model()

        self.model, self.sliceOne, self.sliceTwo, self.sliceThree = self._build_2S_transfer_model()
        self.target_model, self.target_sliceOne, self.target_sliceTwo, self.target_sliceThree = self._build_2S_transfer_model()

        # self.model, self.sliceOne, self.sliceTwo, self.sliceThree = self._build_3S_transfer_model()
        # self.target_model, self.target_sliceOne, self.target_sliceTwo, self.target_sliceThree = self._build_3S_transfer_model()

        self.target_model.set_weights(self.model.get_weights()) # create Q-target network
        
        self.model.summary()

  
    def _build_new_model(self): # private method
        # Slice One
        s1_input_layer = tf.keras.Input(shape=WINDOW_SIZE + (3,))
        s1_conv1 = tf.keras.layers.Conv2D(32, kernel_size=(8, 8),strides=4, activation='relu', name='S1_Conv1', \
                                    kernel_initializer=tf.keras.initializers.VarianceScaling(scale=2.0))(s1_input_layer)
        s1_output = tf.keras.layers.Conv2D(64, kernel_size=(4, 4),strides=2, activation='relu', name='S1_Conv2', \
                                    kernel_initializer=tf.keras.initializers.VarianceScaling(scale=2.0))(s1_conv1)
        s1_model = tf.keras.Model(inputs=s1_input_layer, outputs=s1_output)
        # s1_model.summary()

       # Slice Two
        s2_input_layer = tf.keras.Input(shape=(9,9,64))
        s2_conv1 = tf.keras.layers.Conv2D(64, kernel_size=(3, 3),strides=1, activation='relu', \
                                    kernel_initializer=tf.keras.initializers.VarianceScaling(scale=2.0))(s2_input_layer)
        s2_flat_1 = tf.keras.layers.Flatten(name='S2_Flat1')(s2_conv1)
        s2_output = tf.keras.layers.Dense(512, activation='relu', name='s2_Dense_1', \
                                    kernel_initializer=tf.keras.initializers.VarianceScaling(scale=2.0))(s2_flat_1)
        s2_model = tf.keras.Model(inputs=s2_input_layer, outputs=s2_output)
        s2_model._name = SLICE_TWO_NAME
        # s2_model.summary()

        # Slice Three
        s3_input_layer = tf.keras.Input(shape=(512))
        s3_output = tf.keras.layers.Dense(self.action_size, activation='linear', \
                                    kernel_initializer=tf.keras.initializers.VarianceScaling(scale=2.0))(s3_input_layer)
        s3_model = tf.keras.Model(inputs=s3_input_layer, outputs=s3_output)
        s3_model._name = SLICE_THREE_NAME
        # s3_model.summary()

        full_model_input = tf.keras.Input(shape=(WINDOW_SIZE+(3,)))
        s1_pass = s1_model(full_model_input) #, training=False)
        s2_pass = s2_model(s1_pass)
        s3_final_output = s3_model(s2_pass)

        
        full_model = tf.keras.Model(inputs=full_model_input, outputs=s3_final_output)
        full_model._name = FULL_MODEL_NAME
        # full_model.summary()

        s1_model.trainable = SLICE_ONE_TRAINABLE # ref param above
        s2_model.trainable = SLICE_TWO_TRAINABLE # ref param above
        s3_model.trainable = SLICE_THREE_TRAINABLE # ref param above
        full_model.trainable = FULL_MODEL_TRAINABLE # ref param above
        
        # # Using Nadam because its awesome
        self.optimizer = keras.optimizers.Nadam(learning_rate=self.learning_rate, clipnorm=1.0)
        # # Using Huber loss for stability
        self.loss_function = keras.losses.Huber(reduction=tf.keras.losses.Reduction.SUM)
        
        return full_model, s1_model, s2_model, s3_model
        

    def _build_1S_transfer_model(self): # private method    

        # Slice One
        s1_input_layer = tf.keras.Input(shape=WINDOW_SIZE + (3,))
        s1_model = tf.keras.models.load_model(model_dir + '/' + SLICE_ONE_NAME)
        s1_model._name = SLICE_ONE_NAME
        # s1_model.summary()

        # Slice Two
        s2_input_layer = tf.keras.Input(shape=(9,9,64))
        s2_conv1 = tf.keras.layers.Conv2D(64, kernel_size=(3, 3),strides=1, activation='relu', \
                                    kernel_initializer=tf.keras.initializers.VarianceScaling(scale=2.0))(s2_input_layer)
        s2_flat_1 = tf.keras.layers.Flatten(name='S2_Flat1')(s2_conv1)
        s2_output = tf.keras.layers.Dense(512, activation='relu', name='s2_Dense_1', \
                                    kernel_initializer=tf.keras.initializers.VarianceScaling(scale=2.0))(s2_flat_1)
        s2_model = tf.keras.Model(inputs=s2_input_layer, outputs=s2_output)
        s2_model._name = SLICE_TWO_NAME
        # s2_model.summary()

        # Slice Three
        s3_input_layer = tf.keras.Input(shape=(512))
        s3_output = tf.keras.layers.Dense(self.action_size, activation='linear', \
                                    kernel_initializer=tf.keras.initializers.VarianceScaling(scale=2.0))(s3_input_layer)
        s3_model = tf.keras.Model(inputs=s3_input_layer, outputs=s3_output)
        s3_model._name = SLICE_THREE_NAME
        # s3_model.summary()

        full_model_input = tf.keras.Input(shape=(WINDOW_SIZE+(3,)))
        s1_pass = s1_model(full_model_input) #, training=False)
        s2_pass = s2_model(s1_pass)
        s3_final_output = s3_model(s2_pass)

        
        full_model = tf.keras.Model(inputs=full_model_input, outputs=s3_final_output)
        full_model._name = FULL_MODEL_NAME
        # full_model.summary()

        s1_model.trainable = SLICE_ONE_TRAINABLE # ref param above
        s2_model.trainable = SLICE_TWO_TRAINABLE # ref param above
        s3_model.trainable = SLICE_THREE_TRAINABLE # ref param above
        full_model.trainable = FULL_MODEL_TRAINABLE # ref param above
        
        # # Using Nadam because its awesome
        self.optimizer = keras.optimizers.Nadam(learning_rate=self.learning_rate, clipnorm=1.0)
        # # Using Huber loss for stability
        self.loss_function = keras.losses.Huber(reduction=tf.keras.losses.Reduction.SUM)
        
        return full_model, s1_model, s2_model, s3_model


    def _build_2S_transfer_model(self): # private method    

        # Slice One
        s1_input_layer = tf.keras.Input(shape=WINDOW_SIZE+(3,))
        s1_model = tf.keras.models.load_model(model_dir + '/' + SLICE_ONE_NAME)
        s1_model._name = SLICE_ONE_NAME
        # s1_model.summary()

        # Slice Two
        s2_input_layer = tf.keras.Input(shape=(9,9,64))
        # s2_input_layer = tf.keras.Input(shape=(s1_model.shape[1::1]))
        s2_model = tf.keras.models.load_model(model_dir + '/' + SLICE_TWO_NAME)
        s2_model._name = SLICE_TWO_NAME
        # s2_model.summary()

        # Slice Three
        s3_input_layer = tf.keras.Input(shape=(512))
        s3_output = tf.keras.layers.Dense(self.action_size, activation='linear', \
                                    kernel_initializer=tf.keras.initializers.VarianceScaling(scale=2.0))(s3_input_layer)
        s3_model = tf.keras.Model(inputs=s3_input_layer, outputs=s3_output)
        s3_model._name = SLICE_THREE_NAME
        # s3_model.summary()

        full_model_input = tf.keras.Input(shape=(WINDOW_SIZE+(3,)))
        s1_pass = s1_model(full_model_input) #, training=False)
        s2_pass = s2_model(s1_pass)
        s3_final_output = s3_model(s2_pass)

        
        full_model = tf.keras.Model(inputs=full_model_input, outputs=s3_final_output)
        full_model._name = FULL_MODEL_NAME
        # full_model.summary()

        s1_model.trainable = SLICE_ONE_TRAINABLE # ref param above
        s2_model.trainable = SLICE_TWO_TRAINABLE # ref param above
        s3_model.trainable = SLICE_THREE_TRAINABLE # ref param above
        full_model.trainable = FULL_MODEL_TRAINABLE # ref param above
        
        # # Using Nadam because its awesome
        self.optimizer = keras.optimizers.Nadam(learning_rate=self.learning_rate, clipnorm=1.0)
        # # Using Huber loss for stability
        self.loss_function = keras.losses.Huber(reduction=tf.keras.losses.Reduction.SUM)
        
        return full_model, s1_model, s2_model, s3_model


    def _build_3S_transfer_model(self): # private method    

        # Slice One
        s1_input_layer = tf.keras.Input(shape=WINDOW_SIZE + (3,))
        s1_model = tf.keras.models.load_model(model_dir + '/' + SLICE_ONE_NAME)
        s1_model._name = SLICE_ONE_NAME
        # s1_model.summary()

        # Slice Two
        s2_input_layer = tf.keras.Input(shape=(9,9,64))
        s2_model = tf.keras.models.load_model(model_dir + '/' + SLICE_TWO_NAME)
        s2_model._name = SLICE_TWO_NAME
        # s2_model.summary()

        # Slice Three                                   #### ndim 4?
        s3_input_layer = tf.keras.Input(shape=(512))
        s3_model = tf.keras.models.load_model(model_dir + '/' + SLICE_THREE_NAME)
        s3_model._name = SLICE_THREE_NAME
        # s3_model.summary()

        full_model_input = tf.keras.Input(shape=(WINDOW_SIZE+(3,)))
        s1_pass = s1_model(full_model_input) #, training=False)
        s2_pass = s2_model(s1_pass)
        s3_final_output = s3_model(s2_pass)

        
        full_model = tf.keras.Model(inputs=full_model_input, outputs=s3_final_output)
        full_model._name = FULL_MODEL_NAME
        # full_model.summary()

        s1_model.trainable = SLICE_ONE_TRAINABLE # ref param above
        s2_model.trainable = SLICE_TWO_TRAINABLE # ref param above
        s3_model.trainable = SLICE_THREE_TRAINABLE # ref param above
        full_model.trainable = FULL_MODEL_TRAINABLE # ref param above
        
        # # Using Nadam because its awesome
        self.optimizer = keras.optimizers.Nadam(learning_rate=self.learning_rate, clipnorm=1.0)
        # # Using Huber loss for stability
        self.loss_function = keras.losses.Huber(reduction=tf.keras.losses.Reduction.SUM)
        
        return full_model, s1_model, s2_model, s3_model

    def remember(self, state, action, reward, next_state, done):
        # My newly reimplemented memory, Hopefully it makes us faster
        self.replay_memory.append((state, action, reward, next_state, done))

    def jit_sampler(self, batch_size):
        batch = self.replay_memory.sample(batch_size)
        state_batch, action_batch, reward_batch, next_state_batch, done_batch = [
                np.array([exp[fidx] for exp in batch])
                for fidx in range(5)]
        return state_batch, action_batch, reward_batch, next_state_batch, done_batch


    def train(self, batch_size): # method that trains agent model
        ### The New Implementation
        state_batch, action_batch, reward_batch, next_state_batch, done_batch = self.jit_sampler(batch_size)

        ## This is where all the magic happens
        qValueF = self.target_model.predict_on_batch(next_state_batch) # approximate future reward

        qValueUpdate = reward_batch + self.gamma * tf.reduce_max(qValueF, axis=1)

        qValueUpdate = qValueUpdate * (1 - done_batch) - done_batch

        oneHotMask = tf.one_hot(action_batch, self.action_size)

        with tf.GradientTape() as tape:
            # Train the model on the states and updated Q-values
            OqValue = self.model(state_batch)

            # Apply the masks to the Q-values to get the Q-value for action taken
            OqValue_action = tf.reduce_sum(tf.multiply(OqValue, oneHotMask), axis=1)

            # Calculate loss between new Q-value and old Q-value
            loss = self.loss_function(qValueUpdate, OqValue_action)
            if CHIPPIE_PROGESS_REPORTS:
                  chippie.logLoss(loss)

        if DIAGNOSTIC_MODE:
          print("Q-Values: ", qValueF[1])
          print("Q-Values Update: ", qValueUpdate[1])
          print("Masked Update:   ", oneHotMask[1])
          print("Old Activations: ", OqValue[1])

        # Backpropagation
        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))

        if DIAGNOSTIC_MODE:
          newQ = self.model.predict_step(state_batch)
          print("New Activations: ", newQ[1], "\n")

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay


    def act(self, state):
        if np.random.rand() <= self.epsilon: 
            return random.randrange(self.action_size) # Do something stupid! (i.e. take a random action)
        action_values = self.model.predict_step(tf.expand_dims(tf.convert_to_tensor(state), 0))
        return tf.argmax(action_values[0]).numpy()


    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())
    

    def save(self, name):
        self.model.save_weights(name)


    def load(self, name):
        self.model.load_weights(name)

## Intialize Our Agent
agent = DQNAgent(state_size, action_size)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "s2_MAT_Agent_Testing_v2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 84, 84, 3)]       0
# _________________________________________________________________
# s1_MAT_ImageClassifier_v5 (F (None, 9, 9, 64)          39008
# _________________________________________________________________
# s2_MAT_ImageClassifier_v5 (F (None, 512)               1643072
# _________________________________________________________________
# s3_MAT_ImageClassifier_v2 (F (None, 6)                 3078
# =================================================================
# Total params: 1,685,158
# Trainable params: 1,685,158
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Define Training Loop Environment
#
# Getting your reward function is pretty paramount. In this case we will clip rewards to +1 and -1, with -1 being awarded for reaching a terminal state.

# %%
def myPlayground():

    # Empty Rewards Counter
    reward = 0
    all_rewards = 0
    total_time = 0
    done = False

    # Display in Colab
    if COLAB:
        if RENDER == True:
            done, ax = plt.subplots(1, 1)
            img = ax.imshow(env.render('rgb_array'))    

    # Make Some Starting data
    state = env.reset() # Reset state for new episode
    while agent.replay_memory.size < STARTING_MEMORY_SIZE:
      action = random.randrange(agent.action_size)
      next_frame, reward, done, _ = env.step(action) # Agent sends action to env wrapper and gets feedback

      next_state = next_frame
      if reward > 0.0: # Check and modify reward
        reward = 1.0
      if reward < 0.0:
        reward = -1.0
      if done:
        reward = -1.0
      agent.remember(state, action, reward, next_state, done) # Store sequence in replay memory
      state = next_state # Update state
      if done:
        state = env.reset()
    print("Starting Frames Acquired")

    # Training Loop
    for e in range(n_episodes): ## Go Eat Cherries
        done = False
        time = 0
        game_score = 0
        reward = 0


        state = env.reset() # Reset state for new episode
        
        for skip in range(skip_start): # Skip the start of each game
            env.step(0)

        while not done:
        
            time += 1
            total_time += 1

            # Display
            if RENDER:
                if COLAB:
                    img.set_data(env.render(mode='rgb_array')) 
                    ax.axis('off')
                    ipythondisplay.display(plt.gcf())
                    ipythondisplay.clear_output(wait=True)
                else:
                    env.render()
                    if OBSERVATION_MODE:
                        sleep(0.02)

            # Update Target Network
            if total_time % agent.update_rate == 0:
                agent.update_target_model()
                if CHIPPIE_PROGESS_REPORTS:
                  chippie.q_update()

            # Transition Dynamics
            action = agent.act(state) # Get action from agent
            next_frame, reward, done, _ = env.step(action) # Agent sends action to env wrapper and gets feedback
            next_state = next_frame
            
            # Sternly Validate Reward
            if reward > 0.0: 
              reward = 1.0
              game_score += reward
            if reward < 0.0:
              reward = -1.0
            if done:
              reward = -1.0
              all_rewards += game_score
              if CHIPPIE_PROGESS_REPORTS:
                chippie.dead(score=game_score, totalScore=all_rewards, episode=e, completion_target=n_episodes, survived=time, 
                              experiance=total_time, memory=agent.replay_memory.size, epsilon=agent.epsilon)
              agent.remember(state, action, reward, next_state, done) # Store death in replay memory
              break

            agent.remember(state, action, reward, next_state, done) # Store sequence in replay memory
            state = next_state # Update state

            if agent.replay_memory.size > STARTING_MEMORY_SIZE:
              if not OBSERVATION_MODE:
                if total_time % action_steps == 0:
                  agent.train(BATCH_SIZE)
                  if CHIPPIE_PROGESS_REPORTS:
                    chippie.training(game_score)

        if e % CHECKPOINT_FREQUENCY == 0 and agent.replay_memory.size > STARTING_MEMORY_SIZE+100:
          print("")
          if SLICE_ONE_CHECKPOINT:
              saved_model_path = model_dir + "/ISAR_Production_Models/" + ENVIRONMENT_NAME + SLICE_ONE_NAME + '{:04d}'.format(int(e/CHECKPOINT_FREQUENCY)) 
              tf.saved_model.save(agent.sliceOne, saved_model_path)

          if SLICE_TWO_CHECKPOINT:
              saved_model_path = model_dir + "/ISAR_Production_Models/" + ENVIRONMENT_NAME + SLICE_TWO_NAME + '{:04d}'.format(int(e/CHECKPOINT_FREQUENCY))
              tf.saved_model.save(agent.sliceTwo, saved_model_path)
          
          if SLICE_THREE_CHECKPOINT:
              saved_model_path = model_dir + "/ISAR_Production_Models/" + ENVIRONMENT_NAME + SLICE_TWO_NAME + '{:04d}'.format(int(e/CHECKPOINT_FREQUENCY))
              tf.saved_model.save(agent.sliceTwo, saved_model_path)

          if FULL_MODEL_CHECKPOINT:
              saved_model_path = model_dir + "/ISAR_Production_Models/" + ENVIRONMENT_NAME + FULL_MODEL_NAME + '{:04d}'.format(int(e/CHECKPOINT_FREQUENCY))
              tf.saved_model.save(agent.model, saved_model_path)

          if SAVE_AGENT:
              agent.save(model_dir+ "/ISAR_Production_Models/" + ENVIRONMENT_NAME + FULL_MODEL_NAME + "agent_weights_" + '{:04d}'.format(int(e/CHECKPOINT_FREQUENCY)) +".hdf5")

# %% [markdown]
# #### Interactive Playground (runs automatically)
#
# As the agent finally blitzed through the code, we are getting close to the deadline and what began as an awesome undertaking in abstraction might formally (and temporarily) become a pure comparision of how the transfer learned weights from notebook 1 affect training speed. However, there is still yet another problem, because with only 9 days left to finish, and each test taking a full 12 hours to see results the results come in and the model is still showing no progress. Luckily, one more day of debugging and preparation found a simple bug causing enourmous amounts of pre-buffer data to be labelled terminal. After this fix, the agent has begun to train comparably to the only other working example we found (linked above). This implementation is still slower, however, in that example the baselines wrapper provided by DeepMind is used, which contains significant speed and memory optimizations which unfortunately, only appear to offer frame stacking at 4 frames. Since this would impair our transfer learning basis this is currently the fastest implementation we can provide.

# %% [markdown]
# ##### Launch

# %%
# #### Run From Bottom
## This will take about 3 minutes in colab to gather starting data and output some feedback
## after this you can expect chippieBot limited updates about every 5 minutes for the next 7-12 hours.
myPlayground()
# Out:
# Starting Frames Acquired
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50000/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50000/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20000/assets
#
# Episode: 250/100000, Episode Score: 1.0, Avg Episode Score: 2.892, Survival Time: 51
# Your agent has a running average Score per 100 episodes of: \{^,^}~2.34
# Total Steps: 44740, Memory Size: 100000, Current Epsilon Value: 0.33, Leading Loss: 0.01357/ Trailing Loss: 0.01609
#
# Episode: 500/100000, Episode Score: 3.0, Avg Episode Score: 2.502, Survival Time: 128
# Your agent has a running average Score per 100 episodes of: \{^,^}~2.03
# Total Steps: 71980, Memory Size: 100000, Current Epsilon Value: 0.17, Leading Loss: 0.008607/ Trailing Loss: 0.008546
#
# Episode: 750/100000, Episode Score: 1.0, Avg Episode Score: 2.355, Survival Time: 47
# Your agent has a running average Score per 100 episodes of: \{^,^}~2.13
# Total Steps: 98593, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.008579/ Trailing Loss: 0.008894
#
# Episode: 1000/100000, Episode Score: 1.0, Avg Episode Score: 2.383, Survival Time: 66
# Your agent has a running average Score per 100 episodes of: \{^,^}~2.71
# Total Steps: 131123, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.009055/ Trailing Loss: 0.00887
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50001/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50001/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20001/assets
#
# Episode: 1250/100000, Episode Score: 0, Avg Episode Score: 2.515, Survival Time: 27
# Your agent has a running average Score per 100 episodes of: \{^,^}~3.36
# Total Steps: 167051, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.01141/ Trailing Loss: 0.01166
#
# Episode: 1500/100000, Episode Score: 3.0, Avg Episode Score: 2.73, Survival Time: 127
# Your agent has a running average Score per 100 episodes of: \{^,^}~3.97
# Total Steps: 208631, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.01206/ Trailing Loss: 0.01339
#
# Episode: 1750/100000, Episode Score: 3.0, Avg Episode Score: 3.088, Survival Time: 69
# Your agent has a running average Score per 100 episodes of: \{^,^}~5.86
# Total Steps: 263385, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.01336/ Trailing Loss: 0.01273
#
# Episode: 2000/100000, Episode Score: 0, Avg Episode Score: 3.433, Survival Time: 33
# Your agent has a running average Score per 100 episodes of: \{^,^}~5.53
# Total Steps: 321486, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.01351/ Trailing Loss: 0.01391
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50002/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50002/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20002/assets
#
# Episode: 2250/100000, Episode Score: 9.0, Avg Episode Score: 3.958, Survival Time: 512
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.07
# Total Steps: 398014, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.01395/ Trailing Loss: 0.01522
#
# Episode: 2500/100000, Episode Score: 1.0, Avg Episode Score: 4.364, Survival Time: 66
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.81
# Total Steps: 468171, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.01517/ Trailing Loss: 0.01575
#
# Episode: 2750/100000, Episode Score: 12.0, Avg Episode Score: 4.927, Survival Time: 374
# Your agent has a running average Score per 100 episodes of: \{^,^}~10.7
# Total Steps: 560215, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.01638/ Trailing Loss: 0.01756
#
# Episode: 3000/100000, Episode Score: 0, Avg Episode Score: 5.374, Survival Time: 18
# Your agent has a running average Score per 100 episodes of: \{^,^}~12.1
# Total Steps: 648389, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.01962/ Trailing Loss: 0.02106
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50003/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50003/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20003/assets
#
# Episode: 3250/100000, Episode Score: 4.0, Avg Episode Score: 5.973, Survival Time: 256
# Your agent has a running average Score per 100 episodes of: \{^,^}~12.6
# Total Steps: 753986, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02094/ Trailing Loss: 0.02155
#
# Episode: 3500/100000, Episode Score: 14.0, Avg Episode Score: 6.369, Survival Time: 330
# Your agent has a running average Score per 100 episodes of: \{^,^}~10.7
# Total Steps: 843957, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02415/ Trailing Loss: 0.02241
#
# Episode: 3750/100000, Episode Score: 6.0, Avg Episode Score: 6.709, Survival Time: 261
# Your agent has a running average Score per 100 episodes of: \{^,^}~11.6
# Total Steps: 935468, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02433/ Trailing Loss: 0.02367
#
# Episode: 4000/100000, Episode Score: 7.0, Avg Episode Score: 7.109, Survival Time: 239
# Your agent has a running average Score per 100 episodes of: \{^,^}~13.1
# Total Steps: 1039085, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02121/ Trailing Loss: 0.02199
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50004/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50004/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20004/assets
#
# Episode: 4250/100000, Episode Score: 15.0, Avg Episode Score: 7.397, Survival Time: 575
# Your agent has a running average Score per 100 episodes of: \{^,^}~12.2
# Total Steps: 1138979, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02255/ Trailing Loss: 0.02409
#
# Episode: 4500/100000, Episode Score: 9.0, Avg Episode Score: 7.557, Survival Time: 443
# Your agent has a running average Score per 100 episodes of: \{^,^}~10.9
# Total Steps: 1231564, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.0218/ Trailing Loss: 0.023
#
# Episode: 4750/100000, Episode Score: 2.0, Avg Episode Score: 7.793, Survival Time: 37
# Your agent has a running average Score per 100 episodes of: \{^,^}~12.9
# Total Steps: 1337866, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02174/ Trailing Loss: 0.02136
#
# Episode: 5000/100000, Episode Score: 5.0, Avg Episode Score: 7.973, Survival Time: 206
# Your agent has a running average Score per 100 episodes of: \{^,^}~11.0
# Total Steps: 1438655, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.0221/ Trailing Loss: 0.02392
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50005/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50005/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20005/assets
#
# Episode: 5250/100000, Episode Score: 23.0, Avg Episode Score: 8.134, Survival Time: 877
# Your agent has a running average Score per 100 episodes of: \{^,^}~11.4
# Total Steps: 1537137, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02262/ Trailing Loss: 0.02276
#
# Episode: 5500/100000, Episode Score: 4.0, Avg Episode Score: 8.342, Survival Time: 136
# Your agent has a running average Score per 100 episodes of: \{^,^}~13.1
# Total Steps: 1644141, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02284/ Trailing Loss: 0.022
#
# Episode: 5750/100000, Episode Score: 2.0, Avg Episode Score: 8.497, Survival Time: 199
# Your agent has a running average Score per 100 episodes of: \{^,^}~12.2
# Total Steps: 1743526, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02329/ Trailing Loss: 0.02382
#
# Episode: 6000/100000, Episode Score: 10.0, Avg Episode Score: 8.643, Survival Time: 617
# Your agent has a running average Score per 100 episodes of: \{^,^}~12.7
# Total Steps: 1843989, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02425/ Trailing Loss: 0.02235
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50006/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50006/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20006/assets
#
# Episode: 6250/100000, Episode Score: 40.0, Avg Episode Score: 8.729, Survival Time: 1242
# Your agent has a running average Score per 100 episodes of: \{^,^}~10.6
# Total Steps: 1934560, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02283/ Trailing Loss: 0.02264
#
# Episode: 6500/100000, Episode Score: 8.0, Avg Episode Score: 8.861, Survival Time: 186
# Your agent has a running average Score per 100 episodes of: \{^,^}~14.0
# Total Steps: 2036224, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02353/ Trailing Loss: 0.02306
#
# Episode: 6750/100000, Episode Score: 5.0, Avg Episode Score: 8.912, Survival Time: 114
# Your agent has a running average Score per 100 episodes of: \{^,^}~10.4
# Total Steps: 2127638, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02316/ Trailing Loss: 0.02327
#
# Episode: 7000/100000, Episode Score: 1.0, Avg Episode Score: 8.997, Survival Time: 59
# Your agent has a running average Score per 100 episodes of: \{^,^}~12.9
# Total Steps: 2230022, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02205/ Trailing Loss: 0.02218
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50007/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50007/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20007/assets
#
# Episode: 7250/100000, Episode Score: 6.0, Avg Episode Score: 9.06, Survival Time: 312
# Your agent has a running average Score per 100 episodes of: \{^,^}~9.55
# Total Steps: 2323444, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02518/ Trailing Loss: 0.0237
#
# Episode: 7500/100000, Episode Score: 10.0, Avg Episode Score: 9.175, Survival Time: 406
# Your agent has a running average Score per 100 episodes of: \{^,^}~13.6
# Total Steps: 2428637, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02354/ Trailing Loss: 0.02406
#
# Episode: 7750/100000, Episode Score: 0, Avg Episode Score: 9.223, Survival Time: 28
# Your agent has a running average Score per 100 episodes of: \{^,^}~10.3
# Total Steps: 2523756, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02413/ Trailing Loss: 0.02462
#
# Episode: 8000/100000, Episode Score: 13.0, Avg Episode Score: 9.358, Survival Time: 689
# Your agent has a running average Score per 100 episodes of: \{^,^}~14.1
# Total Steps: 2642307, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02417/ Trailing Loss: 0.02291
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50008/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50008/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20008/assets
#
# Episode: 8250/100000, Episode Score: 3.0, Avg Episode Score: 9.499, Survival Time: 159
# Your agent has a running average Score per 100 episodes of: \{^,^}~15.4
# Total Steps: 2755833, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02476/ Trailing Loss: 0.02384
#
# Episode: 8500/100000, Episode Score: 13.0, Avg Episode Score: 9.593, Survival Time: 212
# Your agent has a running average Score per 100 episodes of: \{^,^}~12.9
# Total Steps: 2860289, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02301/ Trailing Loss: 0.02307
#
# Episode: 8750/100000, Episode Score: 17.0, Avg Episode Score: 9.654, Survival Time: 464
# Your agent has a running average Score per 100 episodes of: \{^,^}~10.5
# Total Steps: 2970171, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02193/ Trailing Loss: 0.02119
#
# Episode: 9000/100000, Episode Score: 4.0, Avg Episode Score: 9.676, Survival Time: 296
# Your agent has a running average Score per 100 episodes of: \{^,^}~9.63
# Total Steps: 3069407, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02146/ Trailing Loss: 0.02162
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50009/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50009/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20009/assets
#
# Episode: 9250/100000, Episode Score: 19.0, Avg Episode Score: 9.749, Survival Time: 493
# Your agent has a running average Score per 100 episodes of: \{^,^}~10.9
# Total Steps: 3184858, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02199/ Trailing Loss: 0.02213
#
# Episode: 9500/100000, Episode Score: 3.0, Avg Episode Score: 9.782, Survival Time: 100
# Your agent has a running average Score per 100 episodes of: \{^,^}~10.4
# Total Steps: 3291703, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.0208/ Trailing Loss: 0.02117
#
# Episode: 9750/100000, Episode Score: 11.0, Avg Episode Score: 9.854, Survival Time: 291
# Your agent has a running average Score per 100 episodes of: \{^,^}~12.1
# Total Steps: 3406305, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02183/ Trailing Loss: 0.02132
#
# Episode: 10000/100000, Episode Score: 6.0, Avg Episode Score: 9.9, Survival Time: 359
# Your agent has a running average Score per 100 episodes of: \{^,^}~12.8
# Total Steps: 3517311, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02263/ Trailing Loss: 0.0226
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50010/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50010/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20010/assets
#
# Episode: 10250/100000, Episode Score: 1.0, Avg Episode Score: 9.917, Survival Time: 54
# Your agent has a running average Score per 100 episodes of: \{^,^}~9.53
# Total Steps: 3618965, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02057/ Trailing Loss: 0.02096
#
# Episode: 10500/100000, Episode Score: 25.0, Avg Episode Score: 9.897, Survival Time: 1115
# Your agent has a running average Score per 100 episodes of: \{^,^}~8.65
# Total Steps: 3709568, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02129/ Trailing Loss: 0.02116
#
# Episode: 10750/100000, Episode Score: 0, Avg Episode Score: 9.911, Survival Time: 33
# Your agent has a running average Score per 100 episodes of: \{^,^}~11.3
# Total Steps: 3810416, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02317/ Trailing Loss: 0.02096
#
# Episode: 11000/100000, Episode Score: 3.0, Avg Episode Score: 9.921, Survival Time: 169
# Your agent has a running average Score per 100 episodes of: \{^,^}~10.6
# Total Steps: 3913078, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02472/ Trailing Loss: 0.02301
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50011/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50011/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20011/assets
#
# Episode: 11250/100000, Episode Score: 3.0, Avg Episode Score: 9.954, Survival Time: 46
# Your agent has a running average Score per 100 episodes of: \{^,^}~11.8
# Total Steps: 4017371, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02394/ Trailing Loss: 0.02482
#
# Episode: 11500/100000, Episode Score: 16.0, Avg Episode Score: 9.975, Survival Time: 330
# Your agent has a running average Score per 100 episodes of: \{^,^}~10.8
# Total Steps: 4117364, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.0241/ Trailing Loss: 0.02616
#
# Episode: 11750/100000, Episode Score: 25.0, Avg Episode Score: 9.972, Survival Time: 1312
# Your agent has a running average Score per 100 episodes of: \{^,^}~10.2
# Total Steps: 4210573, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02413/ Trailing Loss: 0.02808
#
# Episode: 12000/100000, Episode Score: 47.0, Avg Episode Score: 9.996, Survival Time: 1746
# Your agent has a running average Score per 100 episodes of: \{^,^}~11.5
# Total Steps: 4313450, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02629/ Trailing Loss: 0.02716
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50012/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50012/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20012/assets
#
# Episode: 12250/100000, Episode Score: 6.0, Avg Episode Score: 9.997, Survival Time: 205
# Your agent has a running average Score per 100 episodes of: \{^,^}~8.79
# Total Steps: 4416090, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02119/ Trailing Loss: 0.02359
#
# Episode: 12500/100000, Episode Score: 5.0, Avg Episode Score: 9.976, Survival Time: 227
# Your agent has a running average Score per 100 episodes of: \{^,^}~8.98
# Total Steps: 4508287, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02505/ Trailing Loss: 0.02608
#
# Episode: 12750/100000, Episode Score: 4.0, Avg Episode Score: 9.971, Survival Time: 178
# Your agent has a running average Score per 100 episodes of: \{^,^}~10.1
# Total Steps: 4605563, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.027/ Trailing Loss: 0.02761
#
# Episode: 13000/100000, Episode Score: 7.0, Avg Episode Score: 9.95, Survival Time: 218
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.92
# Total Steps: 4697783, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02534/ Trailing Loss: 0.02588
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50013/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50013/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20013/assets
#
# Episode: 13250/100000, Episode Score: 1.0, Avg Episode Score: 9.945, Survival Time: 122
# Your agent has a running average Score per 100 episodes of: \{^,^}~10.6
# Total Steps: 4798133, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02916/ Trailing Loss: 0.02654
#
# Episode: 13500/100000, Episode Score: 2.0, Avg Episode Score: 9.925, Survival Time: 54
# Your agent has a running average Score per 100 episodes of: \{^,^}~10.0
# Total Steps: 4892715, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.0244/ Trailing Loss: 0.02481
#
# Episode: 13750/100000, Episode Score: 48.0, Avg Episode Score: 9.924, Survival Time: 1837
# Your agent has a running average Score per 100 episodes of: \{^,^}~10.4
# Total Steps: 4994124, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02519/ Trailing Loss: 0.02497
#
# Episode: 14000/100000, Episode Score: 17.0, Avg Episode Score: 9.903, Survival Time: 843
# Your agent has a running average Score per 100 episodes of: \{^,^}~9.48
# Total Steps: 5088512, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.0273/ Trailing Loss: 0.02567
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50014/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50014/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20014/assets
#
# Episode: 14250/100000, Episode Score: 11.0, Avg Episode Score: 9.896, Survival Time: 413
# Your agent has a running average Score per 100 episodes of: \{^,^}~9.03
# Total Steps: 5188318, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.0291/ Trailing Loss: 0.03011
#
# Episode: 14500/100000, Episode Score: 13.0, Avg Episode Score: 9.885, Survival Time: 615
# Your agent has a running average Score per 100 episodes of: \{^,^}~9.99
# Total Steps: 5282454, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02709/ Trailing Loss: 0.02902
#
# Episode: 14750/100000, Episode Score: 17.0, Avg Episode Score: 9.869, Survival Time: 729
# Your agent has a running average Score per 100 episodes of: \{^,^}~8.85
# Total Steps: 5376044, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.0257/ Trailing Loss: 0.02472
#
# Episode: 15000/100000, Episode Score: 11.0, Avg Episode Score: 9.832, Survival Time: 652
# Your agent has a running average Score per 100 episodes of: \{^,^}~8.17
# Total Steps: 5464166, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02635/ Trailing Loss: 0.02632
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50015/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50015/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20015/assets
#
# Episode: 15250/100000, Episode Score: 0, Avg Episode Score: 9.803, Survival Time: 47
# Your agent has a running average Score per 100 episodes of: \{^,^}~8.87
# Total Steps: 5554535, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02382/ Trailing Loss: 0.02426
#
# Episode: 15500/100000, Episode Score: 1.0, Avg Episode Score: 9.764, Survival Time: 27
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.2
# Total Steps: 5637354, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.0278/ Trailing Loss: 0.02471
#
# Episode: 15750/100000, Episode Score: 23.0, Avg Episode Score: 9.737, Survival Time: 693
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.01
# Total Steps: 5724642, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.0278/ Trailing Loss: 0.02707
#
# Episode: 16000/100000, Episode Score: 14.0, Avg Episode Score: 9.708, Survival Time: 380
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.51
# Total Steps: 5811702, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02359/ Trailing Loss: 0.02746
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50016/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50016/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20016/assets
#
# Episode: 16250/100000, Episode Score: 9.0, Avg Episode Score: 9.677, Survival Time: 276
# Your agent has a running average Score per 100 episodes of: \{^,^}~6.68
# Total Steps: 5897844, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02615/ Trailing Loss: 0.02404
#
# Episode: 16500/100000, Episode Score: 4.0, Avg Episode Score: 9.639, Survival Time: 171
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.18
# Total Steps: 5982346, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.0254/ Trailing Loss: 0.0226
#
# Episode: 16750/100000, Episode Score: 14.0, Avg Episode Score: 9.597, Survival Time: 530
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.04
# Total Steps: 6067925, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02367/ Trailing Loss: 0.02312
#
# Episode: 17000/100000, Episode Score: 10.0, Avg Episode Score: 9.565, Survival Time: 349
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.21
# Total Steps: 6158048, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02354/ Trailing Loss: 0.02149
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50017/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50017/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20017/assets
#
# Episode: 17250/100000, Episode Score: 2.0, Avg Episode Score: 9.54, Survival Time: 83
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.5
# Total Steps: 6250168, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02349/ Trailing Loss: 0.02383
#
# Episode: 17500/100000, Episode Score: 0, Avg Episode Score: 9.512, Survival Time: 122
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.52
# Total Steps: 6342315, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02506/ Trailing Loss: 0.02104
#
# Episode: 17750/100000, Episode Score: 2.0, Avg Episode Score: 9.478, Survival Time: 65
# Your agent has a running average Score per 100 episodes of: \{^,^}~6.15
# Total Steps: 6426378, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02471/ Trailing Loss: 0.0246
#
# Episode: 18000/100000, Episode Score: 1.0, Avg Episode Score: 9.441, Survival Time: 65
# Your agent has a running average Score per 100 episodes of: \{^,^}~6.39
# Total Steps: 6504988, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02564/ Trailing Loss: 0.02414
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50018/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50018/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20018/assets
#
# Episode: 18250/100000, Episode Score: 4.0, Avg Episode Score: 9.408, Survival Time: 47
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.4
# Total Steps: 6586830, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02514/ Trailing Loss: 0.02509
#
# Episode: 18500/100000, Episode Score: 2.0, Avg Episode Score: 9.376, Survival Time: 75
# Your agent has a running average Score per 100 episodes of: \{^,^}~5.99
# Total Steps: 6667812, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02548/ Trailing Loss: 0.02773
#
# Episode: 18750/100000, Episode Score: 3.0, Avg Episode Score: 9.338, Survival Time: 210
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.07
# Total Steps: 6742030, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.0269/ Trailing Loss: 0.02704
#
# Episode: 19000/100000, Episode Score: 9.0, Avg Episode Score: 9.298, Survival Time: 473
# Your agent has a running average Score per 100 episodes of: \{^,^}~5.16
# Total Steps: 6817433, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02621/ Trailing Loss: 0.02501
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50019/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50019/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20019/assets
#
# Episode: 19250/100000, Episode Score: 12.0, Avg Episode Score: 9.268, Survival Time: 289
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.5
# Total Steps: 6903404, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02517/ Trailing Loss: 0.02366
#
# Episode: 19500/100000, Episode Score: 15.0, Avg Episode Score: 9.235, Survival Time: 731
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.11
# Total Steps: 6983650, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02471/ Trailing Loss: 0.02467
#
# Episode: 19750/100000, Episode Score: 12.0, Avg Episode Score: 9.206, Survival Time: 357
# Your agent has a running average Score per 100 episodes of: \{^,^}~6.09
# Total Steps: 7070779, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02613/ Trailing Loss: 0.02678
#
# Episode: 20000/100000, Episode Score: 4.0, Avg Episode Score: 9.159, Survival Time: 81
# Your agent has a running average Score per 100 episodes of: \{^,^}~5.89
# Total Steps: 7139056, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02309/ Trailing Loss: 0.02364
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50020/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50020/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20020/assets
#
# Episode: 20250/100000, Episode Score: 7.0, Avg Episode Score: 9.144, Survival Time: 291
# Your agent has a running average Score per 100 episodes of: \{^,^}~9.06
# Total Steps: 7231462, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.0259/ Trailing Loss: 0.02307
#
# Episode: 20500/100000, Episode Score: 1.0, Avg Episode Score: 9.129, Survival Time: 26
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.62
# Total Steps: 7322598, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02524/ Trailing Loss: 0.02379
#
# Episode: 20750/100000, Episode Score: 20.0, Avg Episode Score: 9.101, Survival Time: 780
# Your agent has a running average Score per 100 episodes of: \{^,^}~6.32
# Total Steps: 7399192, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.0249/ Trailing Loss: 0.02558
#
# Episode: 21000/100000, Episode Score: 1.0, Avg Episode Score: 9.07, Survival Time: 109
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.05
# Total Steps: 7476573, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02597/ Trailing Loss: 0.02539
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50021/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50021/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20021/assets
#
# Episode: 21250/100000, Episode Score: 0, Avg Episode Score: 9.055, Survival Time: 62
# Your agent has a running average Score per 100 episodes of: \{^,^}~8.46
# Total Steps: 7569113, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02479/ Trailing Loss: 0.026
#
# Episode: 21500/100000, Episode Score: 0, Avg Episode Score: 9.034, Survival Time: 104
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.88
# Total Steps: 7654568, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02384/ Trailing Loss: 0.02288
#
# Episode: 21750/100000, Episode Score: 15.0, Avg Episode Score: 9.009, Survival Time: 992
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.55
# Total Steps: 7735006, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02563/ Trailing Loss: 0.02679
#
# Episode: 22000/100000, Episode Score: 8.0, Avg Episode Score: 8.976, Survival Time: 401
# Your agent has a running average Score per 100 episodes of: \{^,^}~6.09
# Total Steps: 7808452, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02407/ Trailing Loss: 0.02398
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50022/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50022/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20022/assets
#
# Episode: 22250/100000, Episode Score: 1.0, Avg Episode Score: 8.947, Survival Time: 50
# Your agent has a running average Score per 100 episodes of: \{^,^}~6.55
# Total Steps: 7883308, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02708/ Trailing Loss: 0.0238
#
# Episode: 22500/100000, Episode Score: 11.0, Avg Episode Score: 8.928, Survival Time: 566
# Your agent has a running average Score per 100 episodes of: \{^,^}~7.16
# Total Steps: 7969693, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.0286/ Trailing Loss: 0.02723
#
# Episode: 22750/100000, Episode Score: 20.0, Avg Episode Score: 8.908, Survival Time: 883
# Your agent has a running average Score per 100 episodes of: \{^,^}~6.54
# Total Steps: 8051989, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02372/ Trailing Loss: 0.02544
#
# Episode: 23000/100000, Episode Score: 3.0, Avg Episode Score: 8.899, Survival Time: 199
# Your agent has a running average Score per 100 episodes of: \{^,^}~8.83
# Total Steps: 8151362, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02181/ Trailing Loss: 0.02316
#
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50023/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_ImageClassifier_v50023/assets
# INFO:tensorflow:Assets written to: ISAR_Model_Data/ISAR_Production_Models/DemonAttackNoFrameskip-v4s2_MAT_Agent_Testing_v20023/assets
#
# Episode: 23250/100000, Episode Score: 13.0, Avg Episode Score: 8.891, Survival Time: 389
# Your agent has a running average Score per 100 episodes of: \{^,^}~9.19
# Total Steps: 8242941, Memory Size: 100000, Current Epsilon Value: 0.1, Leading Loss: 0.02426/ Trailing Loss: 0.02534

# %% [markdown]
# #### Output
#
# When we are all done building this last box will zip our progress for download so we can continue our work later

# %%
ZIP_OUTPUT = False #@param {type:"boolean"}

# %%
# %%capture
if ZIP_OUTPUT:
  zip = !zip -r ISAR_Model_Data_Output.zip ISAR_Model_Data
